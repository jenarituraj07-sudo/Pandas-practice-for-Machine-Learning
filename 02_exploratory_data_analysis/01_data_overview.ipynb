# %% [markdown]
# ## Part A:- Tennis data set overview

# %%
import pandas as pd

tennis_data = pd.read_csv(r"C:\Users\HP\OneDrive\Desktop\DEALY_PRATICE\00_code_for_GitHub\Pandas-practice-for-Machine-Learning\02_exploratory_data_analysis\australian_open_2025.csv")

"""=> data exception <="""             
print("data_information")
print(tennis_data.info())
print("data description: ", tennis_data.describe())
print("first_five_row: ", tennis_data.head())
print("last_five_columns: ", tennis_data.tail())
print("random_rows: ", tennis_data.sample())


def data_overview(tennis_data):
    return {
        "shape": tennis_data.shape,
        "size": tennis_data.size,
        "duplicate_value_number":tennis_data.duplicated().sum(),
        "row_count": tennis_data.shape[0],
        "columns_count": tennis_data.shape[1],
    }

analysis = data_overview(tennis_data)
print(analysis)
# Out:
# data_information
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2713 entries, 0 to 2712
# Columns: 113 entries, Match_ID to Scrape_Duration_Hours
# dtypes: float64(75), int64(4), object(34)
# memory usage: 2.3+ MB
# None
# data description:         Edition  Prize_Money_USD  Winrate_AI_Pct  Player1_Seed  Player1_Rank  \
# count   2713.0           2713.0     2713.000000   1307.000000   2712.000000
# mean    2025.0        5500000.0       70.195264     13.865340     51.545354
# std        0.0              0.0        0.785587      8.453381     55.821752
# min     2025.0        5500000.0       69.490000      1.000000      1.000000
# 25%     2025.0        5500000.0       69.490000      7.000000     14.000000
# 50%     2025.0        5500000.0       69.490000     14.000000     36.000000
# 75%     2025.0        5500000.0       71.070000     20.000000     70.000000
# max     2025.0        5500000.0       71.070000     32.000000    421.000000
#
# ...
